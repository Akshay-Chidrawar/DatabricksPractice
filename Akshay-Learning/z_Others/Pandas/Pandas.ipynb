# %% [markdown]
# Dataframe is an object of a class which is already designed with some methods and attributes (OOP). It is used to hold and modify data using a tabular format. Its elements can be indexed by a row index and column index.

# %%
import os
os.getcwd()

# %%
import json

f = open ('example-1.json')
data = json.load(f)

display(item)
